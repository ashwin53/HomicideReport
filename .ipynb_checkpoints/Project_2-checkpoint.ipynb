# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 20
#output_notebook()

#from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
# Data Frame from homicide.csv

Homicide = pd.read_csv('D:\Classes\data programming\database.csv')
Homicide = Homicide.replace('Unknown', np.nan)
Homicide = Homicide[Homicide['Victim Age'] <= 100]
Homicide
# Out:
#         Record ID Agency Code                Agency Name       Agency Type  \
# 0               1     AK00101                  Anchorage  Municipal Police
# 1               2     AK00101                  Anchorage  Municipal Police
# 2               3     AK00101                  Anchorage  Municipal Police
# 3               4     AK00101                  Anchorage  Municipal Police
# 4               5     AK00101                  Anchorage  Municipal Police
# 5               6     AK00101                  Anchorage  Municipal Police
# 6               7     AK00101                  Anchorage  Municipal Police
# 7               8     AK00101                  Anchorage  Municipal Police
# 8               9     AK00101                  Anchorage  Municipal Police
# 9              10     AK00101                  Anchorage  Municipal Police
# 10             11     AK00101                  Anchorage  Municipal Police
# 11             12     AK00101                  Anchorage  Municipal Police
# 12             13     AK00101                  Anchorage  Municipal Police
# 13             14     AK00101                  Anchorage  Municipal Police
# 14             15     AK00101                  Anchorage  Municipal Police
# 15             16     AK00101                  Anchorage  Municipal Police
# 16             17     AK00101                  Anchorage  Municipal Police
# 17             18     AK00103                     Juneau  Municipal Police
# 18             19     AK00106                       Nome  Municipal Police
# 19             20     AK00113                     Bethel  Municipal Police
# 20             21     AK00118        North Slope Borough     County Police
# 21             22     AK00118        North Slope Borough     County Police
# 22             23     AK00118        North Slope Borough     County Police
# 23             24     AK00118        North Slope Borough     County Police
# 24             25     AK00118        North Slope Borough     County Police
# 25             26     AK00123                      Kenai  Municipal Police
# 26             27     AKASP00        Alaska State Police      State Police
# 27             28     AKASP00        Alaska State Police      State Police
# 28             29     AKASP00        Alaska State Police      State Police
# 29             30     AKASP00        Alaska State Police      State Police
# ...           ...         ...                        ...               ...
# 638424     638425     WVWSP21     State Police: Kingwood      State Police
# 638425     638426     WVWSP24     State Police: Danville      State Police
# 638426     638427     WVWSP29   State Police: Morgantown      State Police
# 638427     638428     WVWSP29   State Police: Morgantown      State Police
# 638428     638429     WVWSP33  State Police: Parkersburg      State Police
# 638429     638430     WVWSP39    State Police: Princeton      State Police
# 638430     638431     WVWSP49       State Police: Sutton      State Police
# 638431     638432     WVWSP52        State Police: Wayne      State Police
# 638432     638433     WVWSP52        State Police: Wayne      State Police
# 638433     638434     WVWSP53   State Police: Upperglade      State Police
# 638434     638435     WVWSP55        State Police: Welch      State Police
# 638435     638436     WVWSP55        State Police: Welch      State Police
# 638436     638437     WVWSP60   State Police: Williamson      State Police
# 638437     638438     WVWSP65                Sp: Hundred      State Police
# 638438     638439     WVWSP65                Sp: Hundred      State Police
# 638439     638440     WVWSP65                Sp: Hundred      State Police
# 638440     638441     WY00101                    Laramie  Municipal Police
# 638441     638442     WY00300            Campbell County           Sheriff
# 638442     638443     WY01100             Laramie County           Sheriff
# 638443     638444     WY01101                   Cheyenne  Municipal Police
# 638452      Murder or Manslaughter      ...          Not Hispanic
# 638453      Murder or Manslaughter      ...          Not Hispanic
#
#        Perpetrator Sex  Perpetrator Age               Perpetrator Race  \
# 0                 Male               15  Native American/Alaska Native
# 1                 Male               42                          White
# 2                  NaN                0                            NaN
# 3                 Male               42                          White
# 4                  NaN                0                            NaN
# 5                 Male               36                          White
# 6                 Male               27                          Black
# 7                 Male               35                          White
# 8                  NaN                0                            NaN
# 9                 Male               40                            NaN
# 10                 NaN                0                            NaN
# 11                Male               49                          White
# 12                Male               39                          Black
# 13                Male               49                          White
# 14                 NaN                0                            NaN
# 15              Female               29                          Black
# 16                Male               19                            NaN
# 17                Male               23  Native American/Alaska Native
# 18                Male               33  Native American/Alaska Native
# 19                Male               35  Native American/Alaska Native
# 20                Male               29                            NaN
# 21                Male               29                            NaN
# 22                Male               26                            NaN
# 23                Male               41                            NaN
# 24                Male               29                            NaN
# 25                Male               42                          White
# 26                 NaN                0                            NaN
# 27              Female               28  Native American/Alaska Native
# 28              Female               36  Native American/Alaska Native
# 29                Male               61  Native American/Alaska Native
# ...                ...              ...                            ...
# 638424          Female               23                          White
# 638425            Male               45                          White
# 638426            Male               39                          White
# 638427            Male               39                          White
# 638428            Male               23                          White
# 638429            Male               18                          White
# 638430            Male               29                          White
# 638431            Male               22                          White
# 638432            Male               24                          White
# 638433          Female               30                          White
# 638434          Female               35                          White
# 638435          Female               35                          White
# 638436             NaN                0                            NaN
# 638437             NaN               30                            NaN
# 638438             NaN               50                            NaN
# 638439            Male               25                          White
# 638440            Male               20                          White
# 638441            Male               15                          White
# 638442            Male               61                          White
# 638443            Male               16  Native American/Alaska Native
# 638444            Male               35                          White
# 638445            Male               26                          White
# 638446            Male               48                          White
# 638447            Male               22                          White
# 638448            Male               67                          Black
# 638449             NaN                0                            NaN
# 638450            Male               57                          White
# 638451          Female               22         Asian/Pacific Islander
# 638452            Male               31                          White
# 638453          Female               24                          White
#
#        Perpetrator Ethnicity  Relationship         Weapon Victim Count  \
# 0                        NaN  Acquaintance   Blunt Object            0
# 1                        NaN  Acquaintance  Strangulation            0
# 2                        NaN           NaN            NaN            0
# 3                        NaN  Acquaintance  Strangulation            0
# 4                        NaN           NaN            NaN            0
# 5                        NaN  Acquaintance          Rifle            0
# 6                        NaN          Wife          Knife            0
# 7                        NaN          Wife          Knife            0
# 8                        NaN           NaN        Firearm            0
# 9                        NaN           NaN        Firearm            0
# 10                       NaN           NaN            NaN            0
# 11                       NaN      Stranger        Shotgun            0
# 12                       NaN    Girlfriend   Blunt Object            0
# 13                       NaN           NaN           Fall            0
# 14                       NaN           NaN        Handgun            0
# 15                       NaN    Ex-Husband        Handgun            0
# 16                       NaN  Acquaintance          Knife            0
# 17                       NaN       Brother   Blunt Object            0
# 18                       NaN  Acquaintance        Handgun            0
# 19                       NaN       Brother        Handgun            0
# 20                       NaN  Stepdaughter          Rifle            2
# 21                       NaN  Stepdaughter          Rifle            2
# 22                       NaN  Acquaintance          Knife            0
# 638450                 0           FBI
# 638451                 0           FBI
# 638452                 1           FBI
# 638453                 1           FBI
#
# [637480 rows x 24 columns]

# %%
# Perpitrator Sex Total Data frame

Perpetrator_sex= Homicide.groupby('Perpetrator Sex').size().sort_values(ascending=False).to_frame('Total').reset_index()
Perpetrator_sex
# Out:
#   Perpetrator Sex   Total
# 0            Male  399227
# 1          Female   48492

# %%
# Bar chart for the Perpitrator sexes

from bokeh.plotting import figure, output_notebook, show
from bokeh.charts import Bar, Histogram, Line, output_file, show
from bokeh.charts.attributes import cat, color
pd.options.display.max_columns = 20
output_notebook()

Per_sexes = Bar(Perpetrator_sex, 
                values='Total', 
                label=cat(columns='Perpetrator Sex', sort=False), 
                color=color(columns='Perpetrator Sex', palette=['Red'], sort=False), 
                legend=False,
                title='Perpetrator Sexes')


show(Per_sexes)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7cd94bae-c741-423e-8974-48d61457ee45">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c63f0fce-fb66-49c4-af07-df56f2ccfd9e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c63f0fce-fb66-49c4-af07-df56f2ccfd9e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c63f0fce-fb66-49c4-af07-df56f2ccfd9e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c63f0fce-fb66-49c4-af07-df56f2ccfd9e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4b66d1aa-75f3-4f65-a593-a87572d879e2":{"roots":{"references":[{"attributes":{"plot":{"id":"42a762d5-0915-4f9a-ad25-d2d7723f7284","subtype":"Chart","type":"Plot"}},"id":"77ca2ad4-6d52-41aa-9c97-a78c01bddf30","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"77ca2ad4-6d52-41aa-9c97-a78c01bddf30","type":"PanTool"},{"id":"e5a70333-7f5c-4b00-98de-f3a250ef86ec","type":"WheelZoomTool"},{"id":"7704d1e1-a517-4b1a-ac78-6e8792a5eece","type":"BoxZoomTool"},{"id":"84eb7039-cfa5-47fc-bc16-b108e0601054","type":"SaveTool"},{"id":"0c98ea83-fac3-406a-a001-3e88075a47d3","type":"ResetTool"},{"id":"61688a77-9776-4a6d-993a-aa043529176e","type":"HelpTool"}]},"id":"8bfc5f08-cff7-4ce6-93bf-8b07d0bda8db","type":"Toolbar"},{"attributes":{"axis_label":"Perpetrator Sex","formatter":{"id":"4d2ca6cc-d782-4485-bc25-c71e16c18f14","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"42a762d5-0915-4f9a-ad25-d2d7723f7284","subtype":"Chart","type":"Plot"},"ticker":{"id":"b62b1b5a-b758-48b5-8061-21080541308b","type":"CategoricalTicker"}},"id":"4e208045-58ec-41ef-ad8e-83bff92ff21d","type":"CategoricalAxis"},{"attributes":{"callback":null,"end":419188.35},"id":"ab2c33c5-5129-4544-a493-92462eedfee5","type":"Range1d"},{"attributes":{},"id":"c5b10691-78a4-4fee-b60d-5833f4d084d7","type":"BasicTicker"},{"attributes":{"plot":{"id":"42a762d5-0915-4f9a-ad25-d2d7723f7284","subtype":"Chart","type":"Plot"}},"id":"61688a77-9776-4a6d-993a-aa043529176e","type":"HelpTool"},{"attributes":{"data_source":{"id":"5010e094-a13e-452e-b311-1913a8b3a1ec","type":"ColumnDataSource"},"glyph":{"id":"551f4971-a2a0-41fb-9ff3-8cc1ee0be0cf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3db265a8-823e-46d3-8a50-02284e4d9d8f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"42a762d5-0915-4f9a-ad25-d2d7723f7284","subtype":"Chart","type":"Plot"}},"id":"e5a70333-7f5c-4b00-98de-f3a250ef86ec","type":"WheelZoomTool"},{"attributes":{"callback":null,"factors":["Male","Female"]},"id":"140a619e-ca74-4875-9cce-5b2781e55246","type":"FactorRange"},{"attributes":{},"id":"6648bac6-2dbf-4e29-b052-03b30d2e4f3a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"4e208045-58ec-41ef-ad8e-83bff92ff21d","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"d3edf382-e892-4a88-bb02-c165bf7269eb","type":"LinearAxis"}],"renderers":[{"id":"9f55dd5a-7846-48cd-89cd-3a2ee7c43ef7","type":"BoxAnnotation"},{"id":"93a224f4-c9f0-429e-a13e-166b150da669","type":"GlyphRenderer"},{"id":"3db265a8-823e-46d3-8a50-02284e4d9d8f","type":"GlyphRenderer"},{"id":"4e208045-58ec-41ef-ad8e-83bff92ff21d","type":"CategoricalAxis"},{"id":"d3edf382-e892-4a88-bb02-c165bf7269eb","type":"LinearAxis"},{"id":"f173f4b8-9472-4095-8c3b-f54c51a8a87d","type":"Grid"}],"title":{"id":"0153af6a-eab3-4ca4-97f8-2c4b56cc2cab","type":"Title"},"tool_events":{"id":"2b79b79b-20b7-4564-ae39-187d1296dd86","type":"ToolEvents"},"toolbar":{"id":"8bfc5f08-cff7-4ce6-93bf-8b07d0bda8db","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"140a619e-ca74-4875-9cce-5b2781e55246","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"ab2c33c5-5129-4544-a493-92462eedfee5","type":"Range1d"}},"id":"42a762d5-0915-4f9a-ad25-d2d7723f7284","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"2b79b79b-20b7-4564-ae39-187d1296dd86","type":"ToolEvents"},{"attributes":{},"id":"b62b1b5a-b758-48b5-8061-21080541308b","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"551f4971-a2a0-41fb-9ff3-8cc1ee0be0cf","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Perpetrator Sex":["Fem ...

# %%
# Data frame for the Victim Count  

Victim_Count= Homicide.groupby('Victim Count').size().sort_values(ascending=False).to_frame('Total').reset_index()
Victim_Count
# Out:
#     Victim Count   Total
# 0              0  585178
# 1              1   38688
# 2              2    8135
# 3              3    2840
# 4              4    1083
# 5              5     509
# 6              9     290
# 7              6     285
# 8              7     168
# 9             10     160
# 10             8     144

# %%
# Bar chart for Victim Count

Vic_Count = Bar(Victim_Count, 
                values='Total', 
                label=cat(columns='Victim Count', sort=False), 
                color=color(columns='Victim Count', palette=['Green'], sort=False), 
                legend=False,
                title='Victim_Counts')


show(Vic_Count)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5715b42d-6f80-4824-8c03-65b162cc4fe8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5715b42d-6f80-4824-8c03-65b162cc4fe8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5715b42d-6f80-4824-8c03-65b162cc4fe8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5715b42d-6f80-4824-8c03-65b162cc4fe8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3976276f-9da1-4cc7-82d4-974424f88d0b":{"roots":{"references":[{"attributes":{"data_source":{"id":"ba1d701b-3744-4971-95eb-22a2071bdfe8","type":"ColumnDataSource"},"glyph":{"id":"6d3c0e55-25ef-48ae-b07b-1296af5cfb8f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"
type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"i ...

# %%
#Weapon Series used and it's total

Weapon_Series= Homicide.groupby('Weapon').size().sort_values(ascending=False).to_frame('Total').reset_index()
Weapon_Series
# Out:
#            Weapon   Total
# 0         Handgun  317286
# 1           Knife   94897
# 2    Blunt Object   67245
# 3         Firearm   46863
# 4         Shotgun   30707
# 5           Rifle   23336
# 6   Strangulation    8105
# 7            Fire    6149
# 8     Suffocation    3963
# 9             Gun    2197
# 10          Drugs    1581
# 11       Drowning    1203
# 12     Explosives     537
# 13         Poison     453
# 14           Fall     189

# %%
#Bar Chart for Wepaon's used 

Weapon_Ser = Bar(Weapon_Series, 
                values='Total', 
                label=cat(columns='Weapon', sort=False), 
                color=color(columns='Weapon', palette=['Green'], sort=False), 
                legend=False,
                title='Weapon_Series')


show(Weapon_Ser)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6a77c524-6a5e-4899-b9b4-64ee64b0ba09"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6a77c524-6a5e-4899-b9b4-64ee64b0ba09").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a77c524-6a5e-4899-b9b4-64ee64b0ba09");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a77c524-6a5e-4899-b9b4-64ee64b0ba09' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a9a7258d-d0f3-4989-b116-ab724e4a084a":{"roots":{"references":[{"attributes":{"data_source":{"id":"a63d7af4-942d-471e-8dcd-cb4dc1ccd177","type":"ColumnDataSource"},"glyph":{"id":"b49ddc80-5108-4be5-a516-9d59b2e45ccc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"76c17603-0c17-4bce-b719-05f020c1cc95","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Weapon":["Strangulation"],"chart_index":[{"Weapon":"Strangulation"}],"color":["Green"],"fill_alpha":[0.8],"height":[8105.0],"label":[{"Weapon":"Strangulation"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Strangulation"],"y":[4052.5]}},"id":"e4400f00-3e96-4ba7-bc8f-6b7967a13bed","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7015e830-b739-4d68-b09b-3249cbef4795","type":"ColumnDataSource"},"glyph":{"id":"d0d398f2-06ef-493f-aaf4-c7ca295d1660","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a112b737-612d-4a3e-b660-f3f17d5dc9b5","type":"GlyphRenderer"},{"attributes":{},"id":"6e438df2-31e2-4c97-856b-241cee6d3b08","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"52adc8a9-9f5b-4e58-9a84-863a619f0b7f","subtype":"Chart","type":"Plot"}},"id":"747bf62a-cfb3-40d3-b783-15946bbdd796","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0104069e-d2a3-4d74-b0df-977a77162a4f","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Weapon":["Fall"],"chart_index":[{"Weapon":"Fall"}],"color":["Green"],"fill_alpha":[0.8],"height":[189.0],"label":[{"Weapon":"Fall"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Fall"],"y":[94.5]}},"id":"ff93e4ca-813a-49c6-ac9a-aa08b227b3b5","type":"ColumnDataSource"},{"attributes":{"axis_label":"Sum( Total )","formatter":{"id":"6e438df2-31e2-4c97-856b-241cee6d3b08","type":"BasicTickFormatter"},"plot":{"id":"52adc8a9-9f5b-4e58-9a84-863a619f0b7f","subtype":"Chart","type":"Plot"},"ticker":{"id":"c1c31c77-2f3f-4b2d-8f1d-9f06504a9701","type":"BasicTicker"}},"id":"80747131-d06a-40e7-9d32-f6c48d050443","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Weapon":["Fire"],"chart_index":[{"Weapon":"Fire"}],"color":["Green"],"fill_alpha":[0.8],"height":[6149.0],"label":[{"Weapon":"Fire"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Fire"],"y":[3074.5]}},"id":"5b9def9d-85b8-403b-a8b7-d7a0c7dcab65","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["Handgun","Knife","Blunt Object","Firearm","Shotgun","Rifle","Strangulation","Fire","Suffocation","Gun","Drugs","Drowning","Explosives","Poison","Fall"]},"id":"9052dc86-1719-49d2-9e99-72cf601bafe6","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b49ddc80-5108-4be5-a516-9d59b2e45ccc","type":"Rect"},{"attributes":{"plot":null,"text":"Weapon_Series"},"id":"b443daf8-da42-44fd-affb-fb2911f205d4","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e21743d2-bd2c-40a1-aeeb-ec794c1ebadb","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_u ...

# %%
# Top Cities affeted by the homicide data frame

top_cities = Homicide.groupby('City').size().sort_values(ascending=False).to_frame('Total').reset_index().head(15)
top_cities
# Out:
#                     City  Total
# 0            Los Angeles  44501
# 1               New York  38353
# 2                   Cook  22375
# 3                  Wayne  19867
# 4                 Harris  16300
# 5           Philadelphia  12849
# 6                 Dallas  11368
# 7              Jefferson   9527
# 8         Baltimore city   9335
# 9                   Dade   9002
# 10              Maricopa   8563
# 11               Orleans   7892
# 12  District of Columbia   7106
# 13                Orange   6767
# 14                Fulton   6498

# %%
# Bar Chart 

cities = Bar(top_cities,
             values='Total',
             label=cat(columns='City', sort=False),
             color=color(columns='City', palette=['Red'], sort=False),
             legend=False,
             title="Cities")

show(cities)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bb4d3b08-e5dd-4b6f-aad8-9cb6133d31f8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bb4d3b08-e5dd-4b6f-aad8-9cb6133d31f8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bb4d3b08-e5dd-4b6f-aad8-9cb6133d31f8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bb4d3b08-e5dd-4b6f-aad8-9cb6133d31f8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f18cf809-a803-45c4-a1f9-a733d21a085c":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"City":["Philadelphia"],"chart_index":[{"City":"Philadelphia"}],"color":["Red"],"fill_alpha":[0.8],"height":[12849.0],"label":[{"City":"Philadelphia"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Philadelphia"],"y":[6424.5]}},"id":"798d4042-b157-4e3b-8a94-41a6a049a1ed","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"280333a3-8bba-48a5-8ae0-2482c8f0b688","type":"ColumnDataSource"},"glyph":{"id":"0cbbcf02-6ace-4d8e-b69c-3d2f939ae354","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"264cb50c-f234-4a7c-bd8d-bdf3a98ad10c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"City":["Orange"],"chart_index":[{"City":"Orange"}],"color":["Red"],"fill_alpha":[0.8],"height":[6767.0],"label":[{"City":"Orange"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Orange"],"y":[3383.5]}},"id":"66de73e9-4532-4369-bc34-d590896adcb3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c50efdab-59a5-4514-b438-e11ead73b164","type":"ColumnDataSource"},"glyph":{"id":"60c3139d-6516-4f8f-bbc0-c1b0dfe38bea","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d80e8c18-2ee0-4f8f-86b6-f4aa515c8e8b","type":"GlyphRenderer"},{"attributes":{},"id":"b017033e-3245-4d7a-828c-c9f78a33519d","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd942130-1308-4649-b1f3-93b743e9dd4d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"23fa3cfe-26d0-4604-917b-e1c53986a82a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"141fc722-9035-4a3b-bf9f-5b4be26fecfc","type":"Rect"},{"attributes":{"data_source":{"id":"798d4042-b157-4e3b-8a94-41a6a049a1ed","type":"ColumnDataSource"},"glyph":{"id":"7b8a8ca5-3488-408b-9026-795ec7f3538c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4f146480-bb95-486d-b6f9-b745f07b0e1a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8c2b45ad-db14-4441-806a-b4d79a74b762","subtype":"Chart","type":"Plot"}},"id":"195e1056-1bee-403e-950f-eaeede6ce8ea","type":"HelpTool"},{"attributes":{"axis_label":"Sum( Total )","formatter":{"id":"436865c6-7335-4f24-928f-02eaa6742f2a","type":"BasicTickFormatter"},"plot":{"id":"8c2b45ad-db14-4441-806a-b4d79a74b762","subtype":"Chart","type":"Plot"},"ticker":{"id":"b017033e-3245-4d7a-828c-c9f78a33519d","type":"BasicTicker"}},"id":"ec903d78-0a33-4d09-b88f-e3787054ab6b","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7d4e969-75a4-455a-b07c-250978c09789","type":"Rect"},{"attributes":{},"id":"2b48be9e-ad57-4303-903e-2db85506f5a1","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"City":["Baltimore city"],"chart_index":[{"City":"Baltimore city"}],"color":["Red"],"f ...

# %%
# Dataframe for all the Races (Victim Race) and it's Total

df = pd.DataFrame()
df
df['Black'] = Homicide[(Homicide['Victim Race'] == 'Black')]['Year'].value_counts()
df['White'] = Homicide[(Homicide['Victim Race'] == 'White')]['Year'].value_counts()
df['Native'] = Homicide[(Homicide['Victim Race'] == 'Native American/Alaska Native')]['Year'].value_counts()
df['Asian'] = Homicide[(Homicide['Victim Race'] == 'Asian/Pacific Islander')]['Year'].value_counts()
df['Total'] = Homicide[Homicide['Victim Race'] != np.nan]['Year'].value_counts()

df = df.reset_index().rename(columns={'index': 'Year'})
df
# Out:
#     Year  Black  White  Native  Asian  Total
# 0   1993  12269  11260     148    449  24305
# 1   1994  11723  10825     139    393  23224
# 2   1992  11705  11338     160    410  23766
# 3   1991  11190  10714     144    420  22629
# 4   1990  10344  10298     139    221  21231
# 5   1995  10133  10278     160    408  21148
# 6   1980   9842  12269     154    168  23078
# 7   1989   9684   9617     136    226  19864
# 8   1981   9334  11410     136    191  21189
# 9   1996   9033   9284     121    346  18929
# 10  1988   8934   9354     129    186  18761
# 11  1986   8869  10686     172    296  20099
# 12  1982   8726  11337     162    227  20531
# 13  2007   8500   8169     100    281  17273
# 14  1997   8491   8605     139    342  17757
# 15  2006   8454   8161     120    325  17248
# 16  1983   8374  10769     154    264  19635
# 17  1987   8357   9893     141    252  18767
# 18  2005   8044   8130     124    306  16816
# 19  2003   7899   7956     116    324  16497
# 20  2002   7770   7864     129    291  16248
# 21  2004   7610   8007     130    272  16206
# 22  1985   7610  10290     135    254  18367
# 23  2009   7485   7791     119    282  15828
# 24  2008   7448   7566     113    217  15566
# 25  2012   7438   6985      99    273  14920
# 26  1984   7419  10179     126    232  18058
# 27  2010   7414   7177     116    244  15105
# 28  1998   7354   8108     128    238  15990
# 29  2001   7252   7961      99    299  15783
# 30  2011   7245   6955     107    263  14745
# 31  2013   7226   6713     103    241  14445
# 32  2014   7076   6660     111    232  14224
# 33  2000   6921   7210     116    249  14645
# 34  1999   6615   7466     140    266  14603

# %%
#bar chart for the Victim"s Race Yearwise and it's comparison

show(Bar(df,
          values=blend('Black', 'White', 'Asian', 'Native', name='victims', labels_name='victim'),
          label=cat(columns='Year', sort=True),
          stack=cat(columns='victim', sort=True),
          color=color(columns='victim', palette=['Red', 'Green', 'Blue','Yellow'], sort=False),
          legend='top_right',
          title="Victims per Race"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bdb2855fd30e> in <module>()
#       1 #bar chart for the Victim"s Race Yearwise and it's comparison
#       2
# ----> 3 show(Bar(df,
#       4           values=blend('Black', 'White', 'Asian', 'Native', name='victims', labels_name='victim'),
#       5           label=cat(columns='Year', sort=True),
#
# NameError: name 'show' is not defined

# %%
df = pd.DataFrame()
df
df['Black'] = Homicide[(Homicide['Victim Race'] == 'Black')]['Year'].value_counts()
df['White'] = Homicide[(Homicide['Victim Race'] == 'White')]['Year'].value_counts()
df['Native'] = Homicide[(Homicide['Victim Race'] == 'Native American/Alaska Native')]['Year'].value_counts()
df['Asian'] = Homicide[(Homicide['Victim Race'] == 'Asian/Pacific Islander')]['Year'].value_counts()

df = df.reset_index().rename(columns={'index': 'Year'})
df
# Out:
#     Year  Black  White  Native  Asian
# 0   1993  12269  11260     148    449
# 1   1994  11723  10825     139    393
# 2   1992  11705  11338     160    410
# 3   1991  11190  10714     144    420
# 4   1990  10344  10298     139    221
# 5   1995  10133  10278     160    408
# 6   1980   9842  12269     154    168
# 7   1989   9684   9617     136    226
# 8   1981   9334  11410     136    191
# 9   1996   9033   9284     121    346
# 10  1988   8934   9354     129    186
# 11  1986   8869  10686     172    296
# 12  1982   8726  11337     162    227
# 13  2007   8500   8169     100    281
# 14  1997   8491   8605     139    342
# 15  2006   8454   8161     120    325
# 16  1983   8374  10769     154    264
# 17  1987   8357   9893     141    252
# 18  2005   8044   8130     124    306
# 19  2003   7899   7956     116    324
# 20  2002   7770   7864     129    291
# 21  2004   7610   8007     130    272
# 22  1985   7610  10290     135    254
# 23  2009   7485   7791     119    282
# 24  2008   7448   7566     113    217
# 25  2012   7438   6985      99    273
# 26  1984   7419  10179     126    232
# 27  2010   7414   7177     116    244
# 28  1998   7354   8108     128    238
# 29  2001   7252   7961      99    299
# 30  2011   7245   6955     107    263
# 31  2013   7226   6713     103    241
# 32  2014   7076   6660     111    232
# 33  2000   6921   7210     116    249
# 34  1999   6615   7466     140    266

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([6921,7252,7770,7899,7610,8044,8454,8500,7448,7485,7414,7245,7438,7226,7076])
y = np.array([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014])
plt.plot(range(2000,2015), x, 'o--')
plt.xlabel('Blacks as Victims')
plt.ylabel('Years')
plt.plot(range(2000,2015),y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([6921,7252,7770,7899,7610,8044,8454,8500,7448,7485,7414,7245,7438,7226,7076])
x1= np.array([249,299,291,324,272,306,326,281,217,282,244,263,273,241,232])
x2= np.array([116,99,129,116,130,124,120,100,113,119,116,107,99,103,111])
x3= np.array([7210,7691,7864,7956,8007,8130,8161,8169,7566,7791,7177,6955,6985,7226,6660])
y = np.array([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014])
plt.plot(range(2000,2015), x1, 'o--')
plt.plot(range(2000,2015), x, 'o--')
plt.plot(range(2000,2015), x2, 'o--')
plt.plot(range(2000,2015), x3, 'o--')
#legend(x='Blacks',x1='Asian',x2='Native',x3='White','top_right')
plt.legend(loc='upper right')
plt.xlabel('Victims')
plt.ylabel('Years')
plt.plot(range(2000,2015),y)
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
