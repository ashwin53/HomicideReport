# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
xls_file = pd.io.parsers.read_csv("C:/Users/Dravian/Downloads/homicide-reports/database.csv")
xls_file.head()
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type      ...       \
# 0  1980  January         1  Murder or Manslaughter      ...
# 1  1980    March         1  Murder or Manslaughter      ...
# 2  1980    March         2  Murder or Manslaughter      ...
# 3  1980    April         1  Murder or Manslaughter      ...
# 4  1980    April         2  Murder or Manslaughter      ...
#
#   Victim Ethnicity Perpetrator Sex  Perpetrator Age  \
# 0          Unknown            Male               15
# ...

# %%
xls_file=xls_file.groupby(['State','Year']).size().reset_index(name='Counts')
xls_file=xls_file.pivot(index='State',columns='Year',values='Counts')
xls_file.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c6872309c46> in <module>()
# ----> 1 xls_file=xls_file.groupby(['State','Year']).size().reset_index(name='Counts')
#       2 xls_file=xls_file.pivot(index='State',columns='Year',values='Counts')
#       3 xls_file.plot()
#
# NameError: name 'xls_file' is not defined

# %%
frame = DataFrame(xls_file)
frame
# Out:
# Year                    1980    1981    1982    1983    1984    1985    1986  \
# State
# Alabama                513.0   453.0   424.0   372.0   382.0   397.0   407.0
# Alaska                  47.0    69.0    75.0    74.0    52.0    50.0    47.0
# Arizona                293.0   237.0   247.0   225.0   248.0   264.0   321.0
# Arkansas               214.0   209.0   195.0   199.0   183.0   188.0   202.0
# California            3590.0  2885.0  2976.0  2830.0  2888.0  2986.0  3260.0
# Colorado               198.0   230.0   193.0   214.0   192.0   204.0   247.0
# Connecticut            158.0   155.0   164.0   130.0   116.0   124.0   148.0
# Delaware                44.0    41.0    36.0    27.0    24.0    32.0    32.0
# District of Columbia   180.0   232.0   204.0   188.0   175.0   149.0   154.0
# Florida               1508.0  1586.0  1482.0  1262.0  1319.0  1308.0  1427.0
# Georgia                475.0   491.0   574.0   424.0   511.0   557.0   652.0
# ...

# %%
frame.loc['Georgia':'Georgia','1980':'2014']
# Out:
# Year      1980   1981   1982   1983   1984   1985   1986   1987   1988   1989  \
# State
# Georgia  475.0  491.0  574.0  424.0  511.0  557.0  652.0  593.0  731.0  805.0
#
# Year     ...     2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# State    ...
# Georgia  ...    532.0  586.0  696.0  619.0  584.0  565.0  557.0  584.0  567.0
#
# Year      2014
# State
# Georgia  608.0
#
# [1 rows x 35 columns]

# %%
import matplotlib.pyplot as plt
valueX = np.array([475, 491, 574, 424, 511, 557, 652, 593, 731, 805, 737, 733, 681, 764, 699, 644, 523, 531, 
          527, 805, 508, 575, 603, 643, 549, 532, 586, 696, 619, 584, 565, 557, 584, 567, 608])
valueY = np.array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
           1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
           2010, 2011, 2012, 2013, 2014])
plt.plot(range(1980,2015), valueX, 'o--')
plt.xlabel('Years')
plt.ylabel('Homicides in GA')
plt.plot(range(0,805), valueY)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-282-4f2c2deddef1> in <module>()
#       8 plt.xlabel('Years')
#       9 plt.ylabel('Homicides in GA')
# ---> 10 plt.plot(range(0,805), valueY)
#      11 plt.show()
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
# ...

# %%
frame.loc['Florida':'Florida','1980':'2014']
# Out:
# Year     1990  1991    1992    1993    1994    1995    1996    1997    1998  \
# State
# Florida   NaN   1.0  1257.0  1329.0  1278.0  1114.0  1426.0  1068.0  1086.0
#
# Year      1999
# State
# Florida  916.0

# %%
import matplotlib.pyplot as plt
valueX = np.array([1508, 1586, 1482, 1262, 1319, 1308, 1427, 1410, 0, 0, 0, 0, 1257, 1329, 1278, 1114, 1426, 1068, 
          916, 805, 815, 927, 960, 976, 1011, 960, 1210, 1349, 1296, 1162, 1130, 1136, 1170, 1129, 1156])
valueY = np.array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
           1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
           2010, 2011, 2012, 2013, 2014])
plt.plot(range(1980,2015), valueX, 'o--')
plt.xlabel('Years')
plt.ylabel('Homicides in FL')
plt.plot(range(0,1586), valueY)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-291-f0b7cdfa5dbb> in <module>()
#       8 plt.xlabel('Years')
#       9 plt.ylabel('Homicides in FL')
# ---> 10 plt.plot(range(0,1586), valueY)
#      11 plt.show()
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
# ...

# %%
frame.loc['Mississippi':'Mississippi','2000':'2014']
# Out:
# Year          2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# State
# Mississippi  174.0  193.0  194.0  191.0  181.0  164.0  180.0  154.0  185.0
#
# Year          2009   2010   2011   2012   2013   2014
# State
# Mississippi  162.0  174.0  195.0  179.0  147.0  173.0

# %%
import matplotlib.pyplot as plt 
valueX = np.array([218, 246, 232, 198, 165, 180, 170, 178, 152, 169, 178, 219, 209, 234, 232, 201, 190,
                   193, 185, 151, 174, 174, 193, 194, 191, 181, 164, 180, 154, 185, 162, 174, 195, 179, 173]) 
valueY = np.array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996,
                   1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]) 
plt.plot(range(1980,2015), valueX, 'o--') 
plt.xlabel('Years') 
plt.ylabel('Homicides in MS') 
plt.plot(range(0,250), valueY) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-300-d00c769cd113> in <module>()
#       7 plt.xlabel('Years')
#       8 plt.ylabel('Homicides in MS')
# ----> 9 plt.plot(range(0,250), valueY)
#      10 plt.show()
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
# ...

# %%
frame.loc['Alabama':'Alabama','1980':'2014']
# Out:
# Year      1980   1981   1982   1983   1984   1985   1986   1987   1988   1989  \
# State
# Alabama  513.0  453.0  424.0  372.0  382.0  397.0  407.0  336.0  389.0  416.0
#
# Year     ...    2005   2006   2007   2008   2009   2010  2011  2012  2013  \
# State    ...
# Alabama  ...   327.0  358.0  392.0  338.0  318.0  191.0   NaN   2.0   2.0
#
# Year     2014
# State
# Alabama   1.0
#
# [1 rows x 35 columns]

# %%
import matplotlib.pyplot as plt 
valueX = np.array([513, 453, 424, 372, 382, 397, 407, 336, 389, 416, 463, 434, 391, 477, 501, 467, 430,
                   415, 343, 15, 235, 347, 292, 295, 253, 327, 358, 392, 338, 318, 191, 0, 2, 2, 1]) 
valueY = np.array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996,
                   1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]) 
plt.plot(range(1980,2015), valueX, 'o--') 
plt.xlabel('Years') 
plt.ylabel('Homicides in AL') 
plt.plot(range(0,525), valueY) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-306-0ce14828a5d6> in <module>()
#       7 plt.xlabel('Years')
#       8 plt.ylabel('Homicides in AL')
# ----> 9 plt.plot(range(0,525), valueY)
#      10 plt.show()
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
# ...

# %%
frame.loc['Tennessee':'Tennessee','2010':'2014']
# Out:
# Year        2010   2011   2012   2013   2014
# State
# Tennessee  397.0  421.0  440.0  363.0  414.0

# %%
import matplotlib.pyplot as plt 
valueX = np.array([497, 426, 418, 393, 343, 387, 454, 404, 407, 371, 433, 401, 468, 468, 449, 473, 423,
                   439, 436, 411, 435, 444, 457, 426, 382, 463, 444, 445, 412, 486, 397, 421, 440, 363, 414]) 
valueY = np.array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996,
                   1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]) 
plt.plot(range(1980,2015), valueX, 'o--') 
plt.xlabel('Years') 
plt.ylabel('Homicides in TN') 
plt.plot(range(0,500), valueY) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-312-8232748a41b9> in <module>()
#       7 plt.xlabel('Years')
#       8 plt.ylabel('Homicides in TN')
# ----> 9 plt.plot(range(0,500), valueY)
#      10 plt.show()
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# C:\Users\Dravian\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
# ...
